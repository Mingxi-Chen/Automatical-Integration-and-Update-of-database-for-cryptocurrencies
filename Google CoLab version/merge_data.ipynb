# %%
import pandas as pd
# master: master database; file1: last 7 days data
master = pd.read_csv("top10_master_database.csv")
file1 = pd.read_csv("Update_last7Days.csv")
master = pd.concat([master,file1],ignore_index=True)

master.sort_values(["Asset","Date"],inplace=True,ignore_index=True)
master.to_csv("diaonimaSecond.csv",index=False)
